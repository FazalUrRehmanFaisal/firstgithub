# %% [markdown]
# First Program

# %%
print(3+3)
# Out:
# 6

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Python with Fazal")
# Out:
# Python with Fazal

# %% [markdown]
# Day 2

# %% [markdown]
# Operators

# %%
print(3-2)
# Out:
# 1

# %%
4+6
# Out:
# 10

# %%
6//2
# Out:
# 3

# %%
13%2
# Out:
# 1

# %%
6/2
# Out:
# 3.0

# %%
2*3
# Out:
# 6

# %%
2**3
# Out:
# 8

# %%
#PMEDAS

#Paranthesis Exponents Multiply Divide Addition Subtraction

#Left to right for M D & A S

# %% [markdown]
# Strings

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('''Hello World''')
# Out:
# Hello World

# %%
print(" Hello World ")
# Out:
#  Hello World

# %% [markdown]
# Comment

# %%
# print("Hello World")

# %% [markdown]
# Variables

# %%
# Variables : Objects containing specific values

# %%
x = 5
x
# Out:
# 5

# %%
y = "Hello World" #string variable
y
# Out:
# 'Hello World'

# %%
x = x + 10
x
# Out:
# 15

# %%
#types of variables

type(x)
# Out:
# int

# %%
type(y)
# Out:
# str

# %%
# Rules to assign a variable:
# 1- The variable should contain letters, numbers or underscroes
# 2- Do not start with numbers
# 3- Spaces are not allowed
# 4- Do not use keywords used in functions (break, mean ,median, test  etc.)
# 5- Short and descriptive
# 6- Case senstivity (Lowercase, uppercase letters lower case letters should be used)

# %%
fruit_basket = "Mangoes"
print(fruit_basket)
# Out:
# Mangoes

# %%
fruit_basket = 10
print(fruit_basket)
# Out:
# 10

# %%
fruit_basket = 10
print(type(fruit_basket))
# Out:
# <class 'int'>

# %% [markdown]
# Input Variables

# %%
fruit_basket = "Mangoes"
print(fruit_basket)
# Out:
# Mangoes

# %%
#input function

fruit_basket = input("Which is your favourite fruit? ")
print(fruit_basket)
# Out:
# Which is your favourite fruit? Mango
# Mango

# %%
#Input function of 2nd stage

name= input("What is your name? ")
greetings= "Hello!"

print(greetings,name)
# Out:
# What is your name? Fazal
# Hello! Fazal

# %%
#Another way of input function

name= input("What is your name? ")

print("Hello!",name)
# Out:
# What is your name? Fazal
# Hello! Fazal

# %%
#Input function of 3rd stage

name= input("What is your name? ")
age = input("How old are you? ")
greetings= "Hello!"

print(greetings,name,",You are still young")
# Out:
# What is your name? Fazal
# How old are you? 28
# Hello! Fazal ,You are still young

# %%
#Input function of 3rd stage_another way

name= input("What is your name? ")
age = input("How old are you? ")
greetings= "Hello!"

print(greetings,"Your name is ",name,"and Your age is:",age)
# Out:
# What is your name? Fazal
# How old are you? 28
# Hello! Your name is  Fazal and Your age is: 28

# %% [markdown]
# # List

# %%
list1 = [2, "fazal", False]
list1
# Out:
# [2, 'fazal', False]

# %%
type(list1)
# Out:
# list

# %%
list1[2]
# Out:
# False

# %%
list2 = [3,5,"Fazal", 478,53.2,False]
list2
# Out:
# [3, 5, 'Fazal', 478, 53.2, False]

# %%
list1 + list2
# Out:
# [2, 'fazal', False, 3, 5, 'Fazal', 478, 53.2, False]

# %%
list1*2
# Out:
# [2, 'fazal', False, 2, 'fazal', False]

# %%
list1
# Out:
# [2, 'fazal', False]

# %%
a = ["apple","fazal",2,5,False]
x = a.index(False)
x
# Out:
# 4

# %%
list1.reverse()
list1
# Out:
# [False, 'fazal', 2]

# %%
list1.append(2)
list1
# Out:
# [False, 'fazal', 2, 2]

# %%
b = list1.copy()
b
# Out:
# [False, 'fazal', 2, 2]

# %%
list1
# Out:
# [False, 'fazal', 2, 2]

# %%
x = list1.count("fazal")
x
# Out:
# 1

# %%
x1 = [1,2]
list1.extend(x1)
list1
# Out:
# [False, 'fazal', 2, 2, 1, 2]

# %%
list3 = [20,30,40,50,60,100,36,250]
list3
# Out:
# [20, 30, 40, 50, 60, 100, 36, 250]

# %%
len(list3)
# Out:
# 8

# %%
list3.sort()
list3
# Out:
# [20, 30, 36, 40, 50, 60, 100, 250]

# %%
list3 + list1
# Out:
# [20, 30, 36, 40, 50, 60, 100, 250, False, 'fazal', 2, 2, 1, 2]

# %%
list2
# Out:
# [3, 5, 'Fazal', 478, 53.2, False]

# %%
list2.pop(1)
list2
# Out:
# [3, 'Fazal', 478, 53.2, False]

# %%
list3.clear()
list3
# Out:
# []

# %% [markdown]
# # Dictionaries

# %%
# An unordered collection of elements
# Key and value
# curly braces or brackets  {}
# Change the values

# %%
# Food and thier prices

food1 = {"Samosa":30,"Raita":20, "Pakora":100,"Salad":50, "Chicken Rolls":30}
food1
# Out:
# {'Samosa': 30, 'Raita': 20, 'Pakora': 100, 'Salad': 50, 'Chicken Rolls': 30}

# %%
type(food1)
# Out:
# dict

# %%
# extract data

keys1 = food1.keys()
keys1
# Out:
# dict_keys(['Samosa', 'Raita', 'Pakora', 'Salad', 'Chicken Rolls'])

# %%
values1 = food1.values()
values1
# Out:
# dict_values([30, 20, 100, 50, 30])

# %%
#adding new element

food1["Tikki"]=10
food1
# Out:
# {'Samosa': 30,
#  'Raita': 20,
#  'Pakora': 100,
#  'Salad': 50,
#  'Chicken Rolls': 30,
#  'Tikki': 10}

# %%
# update the values

food1["Tikki"] = 15
food1
# Out:
# {'Samosa': 30,
#  'Raita': 20,
#  'Pakora': 100,
#  'Salad': 50,
#  'Chicken Rolls': 30,
#  'Tikki': 15}

# %%
food2 = {"Dates":50, "Chocolates":200, "Sawayyan":1000}
food2
# Out:
# {'Dates': 50, 'Chocolates': 200, 'Sawayyan': 1000}

# %%
#concatenate
food1.update(food2)
food1
# Out:
# {'Samosa': 30,
#  'Raita': 20,
#  'Pakora': 100,
#  'Salad': 50,
#  'Chicken Rolls': 30,
#  'Tikki': 15,
#  'Dates': 50,
#  'Chocolates': 200,
#  'Sawayyan': 1000}

# %%
food3 = food1.copy()
food3
# Out:
# {'Samosa': 30,
#  'Raita': 20,
#  'Pakora': 100,
#  'Salad': 50,
#  'Chicken Rolls': 30,
#  'Tikki': 15,
#  'Dates': 50,
#  'Chocolates': 200,
#  'Sawayyan': 1000}

# %%
food4 = dict.fromkeys(food3)
food4
# Out:
# {'Samosa': None,
#  'Raita': None,
#  'Pakora': None,
#  'Salad': None,
#  'Chicken Rolls': None,
#  'Tikki': None,
#  'Dates': None,
#  'Chocolates': None,
#  'Sawayyan': None}

# %%
food5 = food3.get("Pakora")
food5
# Out:
# 100

# %%
food6 = food3.items()
food6
# Out:
# dict_items([('Samosa', 30), ('Raita', 20), ('Pakora', 100), ('Salad', 50), ('Chicken Rolls', 30), ('Tikki', 15), ('Dates', 50), ('Chocolates', 200), ('Sawayyan', 1000)])

# %%
food7 = food3.pop("Dates")
food7
# Out:
# 50

# %%
food8 = food3.popitem()
food8
# Out:
# ('Sawayyan', 1000)

# %%
food9 = food3.setdefault("Dates","100")
food9
# Out:
# '100'

# %%
food10 = food3.values()
food10
# Out:
# dict_values([30, 20, 100, 50, 30, 15, 200, '100'])

# %%
food3.clear()
food3
# Out:
# {}

# %% [markdown]
# # Set

# %%
# unordered and unindexed
# use with { }
# no duplicates allowed

# %%
s1 = {1,2.1,5.2,"Fazal","Codanics","SK"}
s1
# Out:
# {1, 2.1, 5.2, 'Codanics', 'Fazal', 'SK'}

# %%
s1.add("Fazal")
s1
# Out:
# {1, 2.1, 5.2, 'Codanics', 'Fazal', 'SK'}

# %%
s1.add("Gwangju")
s1
# Out:
# {1, 2.1, 5.2, 'Codanics', 'Fazal', 'Gwangju', 'SK'}

# %%
s1.remove(5.2)
s1
# Out:
# {1, 2.1, 'Codanics', 'Fazal', 'Gwangju', 'SK'}

# %%
s2 = {3,5.4,"ABCD","Khi","Pak"}
s1.difference(s2)
s1
# Out:
# set()

# %%
s4 = {2.1,5.2,"ABCD","Khi","Codanics"}
s5 = {1,2.1,5.2,"Fazal","Codanics","SK"}

s4.difference_update(s5)
s4
# Out:
# {'ABCD', 'Khi'}

# %%
s6 = {1,2.1,5.2,"Fazal","Codanics","SK"}
s6
# Out:
# {1, 2.1, 5.2, 'Codanics', 'Fazal', 'SK'}

# %%
s6.discard("SK")
s6
# Out:
# {1, 2.1, 5.2, 'Codanics', 'Fazal'}

# %%
s7 = {1,2.1,5.2,"Fazal","Codanics","SK"}

s7.intersection(s5)
s7
# Out:
# {1, 2.1, 5.2, 'Codanics', 'Fazal', 'SK'}

# %%
s7.intersection_update(s6)
s7
# Out:
# {1, 2.1, 5.2, 'Codanics', 'Fazal'}

# %%
s8 = {1,2.4,5.2,"Faz","Cod","SK"}

s8.isdisjoint(s7)
# Out:
# False

# %%
s7.issubset(s6)
# Out:
# True

# %%
s8.issuperset(s7)
# Out:
# False

# %%
s8.pop()
s8
# Out:
# {2.4, 5.2, 'Cod', 'Faz', 'SK'}

# %%
s8.remove("Cod")
s8
# Out:
# {2.4, 5.2, 'Faz', 'SK'}

# %%
s8.symmetric_difference(s7)
# Out:
# {1, 2.1, 2.4, 'Codanics', 'Faz', 'Fazal', 'SK'}

# %%
s8.symmetric_difference_update(s7)
s8
# Out:
# {2.4, 5.2, 'Faz', 'SK'}

# %%
s8.union(s7)
# Out:
# {1, 2.1, 2.4, 5.2, 'Codanics', 'Faz', 'Fazal', 'SK'}

# %%
s8.clear()
s8
# Out:
# set()
